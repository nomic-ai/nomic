# %%
from nomic.aws.sagemaker import batch_transform

# %%
batch_transform(
    "s3://batch-transform-test/batch_transform.csv",
    "s3://batch-transform-test/",
    "us-east-2",
    model_name = None,
    arn='arn:aws:sagemaker:us-east-2:339712780244:model-package/nomic-embed-text-v-1-5-03-27-2024',
    role = 'arn:aws:iam::339712780244:role/sagemaker-executor',
    max_payload = 6,
    n_instances = 1
)
# Out:
# INFO:botocore.credentials:Found credentials from IAM Role: aws-sagemaker
# INFO:sagemaker:Creating model with name: nomic-embed-text-v-1-5-03-27-2024
# WARNING:sagemaker:Using already existing model: nomic-embed-text-v-1-5-03-27-2024
# INFO:sagemaker:Creating transform job with name: nomic-embed-text-v-1-5-03-27-2024-2024-03-27-18-48-58-601
# ...............................................+ TRITONSERVER_MODEL_REPOSITORY=/opt/ml/model
# + TRITONSERVER_MODEL_REPOSITORY=/opt/ml/model
# + python3 src/server.py
# + tritonserver --model-repository=/opt/ml/model --rate-limit-resource MEM:1 --rate-limit execution_count --http-thread-count 64
# I0327 18:56:53.284970 21 pinned_memory_manager.cc:241] Pinned memory pool is created at '0x7fcefe000000' with size 268435456
# I0327 18:56:53.285455 21 cuda_memory_manager.cc:107] CUDA memory pool is created on device 0 with size 67108864
# I0327 18:56:53.288226 21 model_lifecycle.cc:461] loading: nomic-embed-text-v1.5:1
# ...
